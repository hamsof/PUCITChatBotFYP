# %% [markdown]
# # DEEP LEARNING

# %% [markdown]
# ![DL1.PNG](attachment:DL1.PNG)

# %% [markdown]
# ![MLvsDL.jpg](attachment:MLvsDL.jpg)

# %% [markdown]
# ## Why Deep Learning

# %% [markdown]
# Hand engineered features are time consuming, brittle and not scalable in practice, as we have hundreds and millions of datapoints in hand wouldn't it be awesome if the model can extract features itself.

# %% [markdown]
# ![1_KYUUg9JC6InYe-VNPMDzAA.png](attachment:1_KYUUg9JC6InYe-VNPMDzAA.png)

# %% [markdown]
# # Perceptron

# %% [markdown]
# The structural building block of deep learning is called perceptron

# %% [markdown]
# ![perceptrn-2.PNG](attachment:perceptrn-2.PNG)

# %% [markdown]
# ## Bias in Perceptron

# %% [markdown]
# Neural network bias can be defined as the constant which is added to the product of features and weights. It is used to offset the result. It helps the models to shift the activation function towards the positive or negative side. While changing the values of ‘w’, there is no way we can shift the origin of the activation function.On changing the values of ‘w’, only the steepness of the curve will change. There is only one way to shift the origin and that is to include bias ‘b’.

# %% [markdown]
# ![bias.PNG](attachment:bias.PNG)

# %% [markdown]
# # Activation Functions

# %% [markdown]
# An Activation Function decides whether a neuron should be activated or not. This means that it will decide whether the neuron’s input to the network is important or not in the process of prediction using simpler mathematical operations.Simply to transform data in a form so it can become the input of other layer. The purpose of the activation function is to introduce non-linearity into the output of a neuron. All hidden layers typically use the same activation function. The output layer will typically use a different activation function from the hidden layers and is dependent upon the type of prediction required by the model
#
#         Linear Activation Functions
#         Non-Linear Activation Functions

# %% [markdown]
# ![act.PNG](attachment:act.PNG)

# %% [markdown]
# ## Different Common Activation Functions

# %% [markdown]
# ![threshold.PNG](attachment:threshold.PNG)

# %% [markdown]
# ![sigmoid.PNG](attachment:sigmoid.PNG)

# %% [markdown]
# This function reduces extreme values or outliers in data without removing them.
#
# It converts independent variables of near infinite range into simple probabilities
# between 0 and 1, and most of its output will be very close to 0 or 1.

# %% [markdown]
# ![Relu.PNG](attachment:Relu.PNG)

# %% [markdown]
# The rectified linear activation function or ReLU for short is a piecewise linear function that will output the input directly if it is positive, otherwise, it will output zero

# %% [markdown]
# ![tanh.PNG](attachment:tanh.PNG)

# %% [markdown]
# Unlike the Sigmoid function, the normalized range of tanh is –1 to 1 The advantage of tanh is
# that it can deal more easily with negative numbers

# %% [markdown]
# ## Activation Function Example

# %% [markdown]
# In a bank system we have a customer and on the basis of different parameters of customer we have to decide whether customer ca survive in bank or not. 0 not survive, 1 for survive
# ![actexample.PNG](attachment:actexample.PNG)

# %% [markdown]
# # Loss Function

# %% [markdown]
# A loss function is a function that compares the target and predicted output values; measures how well the neural network models the training data. When training, we aim to minimize this loss between the predicted and target outputs.
# ![cls.PNG](attachment:cls.PNG)

# %% [markdown]
# ![mse.PNG](attachment:mse.PNG)

# %% [markdown]
# # Forward Propagation

# %% [markdown]
# Forward Propagation is the way to move from the Input layer (left) to the Output layer (right) in the neural network.
# ![forward-2.PNG](attachment:forward-2.PNG)

# %% [markdown]
# # Backward Propagation

# %% [markdown]
# It is the method of
# fine-tuning the weights of a neural net based on the error rate obtained in the
# previous epoch (i.e., iteration). Proper tuning of the weights allows you to reduce
# error rates and to make the model reliable by increasing its generalization.

# %% [markdown]
# ![bp.PNG](attachment:bp.PNG)
