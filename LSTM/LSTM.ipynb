# %% [markdown]
# # LSTM

# %% [markdown]
# **Vanishing Gradient Problem**<br>
# When number of hidden layers grow, gradient becomes very small and weights will hardly change. When there are more layers in the network, the value of the product of derivative decreases until at some point the partial derivative of the loss function approaches a value close to zero, and the partial derivative vanishes. This will hamper the learning rate.<br>
# **Why LSTM?**<br>
# We solve Vanishing gradient problem with LSTM. <br>
# `LSTM stands for Long-Short Term Memory is also a steping stone to learning about Transformers`<br>
# **How can we use a feedback loop to unroll a network that works well with different amount of sequential data?**<br>
# In LSTM we can use two diffrent paths instead of one feedback loop to make predictions.One is for **long term memories** and one is for **short term memories**.<br>
# <br>Each LSTM state contains:
# 1. Cell state = Long Term Memory
# 2. Hidden state
# 2. Forget gate
# 3. Input gate
# 4. Output gate

# %% [markdown]
# ![lstm-1.PNG](attachment:lstm-1.PNG)

# %% [markdown]
# LSTM uses both sigmoid and tanh functions.<br>
# **Sigmoid**<br>
# It takes any x-axis coordinate and turn it into y-axis coordinate y-axis coordinate between 0 and 1.<br>
# **Tanh**<br>
# It takes any x-axis coordinate and turn it into y-axis coordinate y-axis coordinate between -1 and 1.<br>

# %% [markdown]
# ![WhatsApp%20Image%202023-01-12%20at%207.25.30%20PM.jpeg](attachment:WhatsApp%20Image%202023-01-12%20at%207.25.30%20PM.jpeg)

# %% [markdown]
# **<br>How LSTM works?**<br>
# 1. This is the **cell state** that represents the Long-Term Memory. It can be changed by multiplicaion and then addition. It can't be modified directly beacuse there are no weightd and biases.<br>
# This lack of weights alows th LTM to flow through a series of unrolled units without causing the gradient to explode and vanish.<br>
# 2. The **hidden state** represents the Short-Term Memory. It is directly connected to weights that can modify it.<br>
# 3. The **forget gate**  determines what percentage of Long-Term Memory will be remembered.<br>
# 4. The **input gate** combines short term memory and input to create a potential long term memory. and 1st gate determines what percentage of that potential memory to add to the LTM.<br>
# 5. The **output gate** updates the short term memory. We use new LTM as input  to Tanh function and the return value represents potential short term memory. Now LSTM has to decide how much of this potentiak memory to pass on and this is done using the exact same methd we used earlier.<br>

# %% [markdown]
# ![lstm-3.PNG](attachment:lstm-3.PNG)

# %% [markdown]
# Let the input at time t in the LSTM cell be x<sub>t</sub>, the cell state from time t-1 and t be c<sub>t-1</sub> and c<sub>t</sub> and the output for time t-1 and t be h<sub>t-1</sub> and h<sub>t</sub> . <br>
# ![WhatsApp%20Image%202023-01-12%20at%207.26.27%20PM.jpeg](attachment:WhatsApp%20Image%202023-01-12%20at%207.26.27%20PM.jpeg)

# %% [markdown]
# **Example**<br>
# Given this sequential data, we want the LSTM to remember what happened on Day 1 so it can correctly predict what happened on Day 5.
# ![companyA.PNG](attachment:companyA.PNG)

# %% [markdown]
# ![WhatsApp%20Image%202023-01-12%20at%207.17.54%20PM.jpeg](attachment:WhatsApp%20Image%202023-01-12%20at%207.17.54%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-01-12%20at%207.21.05%20PM.jpeg](attachment:WhatsApp%20Image%202023-01-12%20at%207.21.05%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-01-12%20at%207.22.59%20PM.jpeg](attachment:WhatsApp%20Image%202023-01-12%20at%207.22.59%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-01-12%20at%207.24.15%20PM.jpeg](attachment:WhatsApp%20Image%202023-01-12%20at%207.24.15%20PM.jpeg)

# %% [markdown]
# As, we can see final **Short Term Memory** is 0.0 and that means that the output from **LSTM** correctly predicts Company A's value for **Day 5**.
